# %% [markdown]
# ## **Tokenizando**

# %%
import tiktoken

# Usamos gpt-4o-mini que é compatível com os modelos atuais caso o 4.1-mini não exista na sua versão
encoding = tiktoken.encoding_for_model("gpt-4o-mini")

tokens = encoding.encode("Oi, meu nome é Ramon e eu gosto de banoffee")

# %%
tokens
# Out:
# [75561, 11, 18477, 16667, 1212, 150502, 319, 5658, 64701, 334, 9171, 26458]

# %%
for token_id in tokens:
    token_text = encoding.decode([token_id])
    print(f"{token_id} = {token_text}")
# Out:
# 75561 = Oi
# 11 = ,
# 18477 =  meu
# 16667 =  nome
# 1212 =  é
# 150502 =  Ramon
# 319 =  e
# 5658 =  eu
# 64701 =  gosto
# 334 =  de
# 9171 =  ban
# 26458 = offee

# %% [markdown]
# ## **Testando memória**

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv('OPENROUTER_API_KEY')

if not api_key:
    print("Nenhuma chave de API da OpenRouter foi encontrada - por favor verifique o seu arquivo .env!")
elif not api_key.startswith("sk-or-"):
    print("Uma chave de API foi encontrada, mas não começa com sk-or-; por favor, verifique se você está usando a chave correta da OpenRouter")
else:
    print("Chave de API da OpenRouter encontrada e parece boa até agora!")
# Out:
# Chave de API da OpenRouter encontrada e parece boa até agora!

# %%
import os
from dotenv import load_dotenv

load_dotenv(override=True)
api_key = os.getenv('OPENROUTER_API_KEY')

if not api_key:
    print("Nenhuma chave de API da OpenRouter foi encontrada - por favor verifique o seu arquivo .env!")
elif not api_key.startswith("sk-or-"):
    print("Uma chave de API foi encontrada, mas não começa com sk-or-; por favor, verifique se você está usando a chave correta da OpenRouter")
else:
    print("Chave de API da OpenRouter encontrada e parece boa até agora!")
# Out:
# Chave de API da OpenRouter encontrada e parece boa até agora!

# %%
from openai import OpenAI

# Configurando o cliente da OpenAI para usar a OpenRouter via base_url
openai = OpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key=api_key
)

# %%
messages = [
    {"role": "system", "content": "Você é um assistente útil"},
    {"role": "user", "content": "Oi! Eu sou o Ramon!"}
    ]

# %%
# Atualizado para o formato de modelo exigido pela OpenRouter
response = openai.chat.completions.create(model="nvidia/nemotron-3-super-120b-a12b:free", messages=messages)
response.choices[0].message.content
# Out:
# 'Oi, Ramon! 😊 Como posso ajudar você hoje?'

# %%
messages = [
    {"role": "system", "content": "Você é um assistente útil"},
    {"role": "user", "content": "Qual é o meu nome?"}
    ]

# %%
response = openai.chat.completions.create(model="nvidia/nemotron-3-super-120b-a12b:free", messages=messages)
response.choices[0].message.content
# Out:
# 'Não sei qual é oseu nome, pois não tenho acesso a informações pessoais a menos que você as compartilhe comigo. Como posso ajudá-lo? 😊'

# %% [markdown]
# Cada chamada para um LLM é completamente SEM ESTADO (STATELESS). É uma chamada totalmente nova, em todas as vezes.

# %%
messages = [
    {"role": "system", "content": "Você é um assistente útil"},
    {"role": "user", "content": "Oi! Eu sou o Ramon!"},
    {"role": "assistant", "content": "Oi Ramon! Como posso ajudá-lo hoje?"},
    {"role": "user", "content": "Qual é o meu nome?"}
    ]

# %%
response = openai.chat.completions.create(model="nvidia/nemotron-3-super-120b-a12b:free", messages=messages)
response.choices[0].message.content
# Out:
# 'Seu nome é Ramon! 😊  Lembrei perfeitamente do que você disse no início: "Oi! Eu sou o Ramon!".  \nComo posso ajudá-lo hoje?'
